# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000001F6E1B59310>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title('Line Gragh')
# Out:
# Text(0.5, 1.0, 'Line Gragh')

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\User\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['cmmi10',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmr10',
#  'DejaVu Sans Mono',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'cmb10',
#  'STIXSizeThreeSym',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXGeneral',
#  'cmtt10',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'Stencil',
#  'Poor Richard',
#  'Tw Cen MT',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Batang',
#  'Jokerman',
#  'Century Gothic',
#  'Cooper Black',
#  'Sitka',
#  'Bookman Old Style',
#  'Gill Sans Ultra Bold',
#  'Papyrus',
#  'Book Antiqua',
#  'Microsoft JhengHei',
#  'Tw Cen MT',
#  'Franklin Gothic Medium Cond',
#  'Footlight MT Light',
#  'Times New Roman',
#  'HYGothic-Medium',
#  'Lucida Calligraphy',
#  'Perpetua',
#  'Microsoft YaHei',
#  'Century Schoolbook',
#  'Californian FB',
#  'Arial',
#  'Copperplate Gothic Light',
#  'Courier New',
#  'HYGraphic-Medium',
#  'Gabriola',
#  'NewJumja',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'Candara',
#  'Comic Sans MS',
#  'Century Schoolbook',
#  'Gadugi',
#  'MV Boli',
#  'HYSinMyeongJo-Medium',
#  'Cambria',
#  'Microsoft New Tai Lue',
#  'MoeumT R',
#  'Microsoft PhagsPa',
#  'SimSun-ExtB',
#  'Palatino Linotype',
#  'Perpetua',
#  'Palatino Linotype',
#  'HYPMokGak-Bold',
#  'MS Reference Sans Serif',
#  'Modern No. 20',
#  'Bodoni MT',
#  'HCR Dotum Ext',
#  'Matura MT Script Capitals',
#  'Sitka',
#  'Castellar',
#  'Blackadder ITC',
#  'Bookman Old Style',
#  'Wingdings',
#  'Century',
#  'HYGothic-Extra',
#  'Yu Gothic',
#  'Leelawadee UI',
#  'Myanmar Text',
#  'Cambria',
#  'Yet R',
#  'Arial',
#  'Gigi',
#  'Tahoma',
#  'Lucida Sans',
#  'Cambria',
#  'Lucida Sans Unicode',
#  'Viner Hand ITC',
#  'HancomEQN',
#  'Magic R',
#  'Courier New',
#  'Bradley Hand ITC',
#  'Franklin Gothic Demi',
#  'Tw Cen MT Condensed Extra Bold',
#  'Gill Sans MT',
#  'Verdana',
#  'Gadugi',
#  'Felix Titling',
#  'Bodoni MT',
#  'HYMyeongJo-Extra',
#  'Book Antiqua',
#  'Malgun Gothic',
#  'Monotype Corsiva',
#  'Lucida Bright',
#  'Harrington',
#  'Gill Sans Ultra Bold Condensed',
#  'Eras Demi ITC',
#  'Segoe UI',
#  'Berlin Sans FB',
#  'Times New Roman',
#  'Lucida Handwriting',
#  'Tahoma',
#  'Lucida Fax',
#  'Corbel',
#  'Malgun Gothic',
#  'Parchment',
#  'Wingdings 2',
#  'Eras Light ITC',
#  'Franklin Gothic Medium',
#  'Verdana',
#  'HCR Dotum',
#  'HCR Dotum',
#  'Cambria',
#  'Franklin Gothic Heavy',
#  'MS Gothic',
#  'SimSun',
#  'Microsoft JhengHei',
#  'Georgia',
#  'Noto Sans KR',
#  'Copperplate Gothic Bold',
#  'Garamond',
#  'HCR Batang',
#  'Impact',
#  'Agency FB',
#  'Lucida Fax',
#  'Malgun Gothic',
#  'Segoe UI Symbol',
#  'Rockwell',
#  'Yu Gothic',
#  'Times New Roman',
#  'Chiller',
#  'Century Gothic',
#  'Microsoft YaHei',
#  'Rockwell Extra Bold',
#  'Candara',
#  'Calisto MT',
#  'Perpetua Titling MT',
#  'Segoe UI Historic',
#  'Lucida Fax',
#  'Haan Wing2',
#  'Trebuchet MS',
#  'Segoe UI',
#  'Bahnschrift',
#  'Lucida Sans',
#  'Gill Sans MT Ext Condensed Bold',
#  'Californian FB',
#  'Segoe Print',
#  'Bookman Old Style',
#  'Segoe UI',
#  'Ebrima',
#  'Playbill',
#  'Noto Serif KR',
#  'Lucida Sans Typewriter',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'Haettenschweiler',
#  'Calibri',
#  'Pristina',
#  'Rockwell',
#  'Arial',
#  'Showcard Gothic',
#  'Lucida Sans Typewriter',
#  'Tempus Sans ITC',
#  'HYPost-Light',
#  'Franklin Gothic Demi Cond',
#  'Bernard MT Condensed',
#  'Constantia',
#  'MT Extra',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'French Script MT',
#  'Calisto MT',
#  'Lucida Bright',
#  'Calibri',
#  'Candara',
#  'Imprint MT Shadow',
#  'Verdana',
#  'Hancom Gothic',
#  'Elephant',
#  'Constantia',
#  'HCR Batang Ext',
#  'HCR Batang ExtB',
#  'Microsoft JhengHei',
#  'Franklin Gothic Medium',
#  'SimSun-ExtG',
#  'Britannic Bold',
#  'Tw Cen MT Condensed',
#  'Segoe UI',
#  'HYHeadLine-Medium',
#  'Corbel',
#  'Lucida Fax',
#  'Arial',
#  'OCR A Extended',
#  'Ink Free',
#  'Georgia',
#  'High Tower Text',
#  'Goudy Old Style',
#  'New Gulim',
#  'Agency FB',
#  'MS Reference Specialty',
#  'Niagara Solid',
#  'Segoe Fluent Icons',
#  'Niagara Engraved',
#  'Ravie',
#  'Consolas',
#  'Trebuchet MS',
#  'Gill Sans MT',
#  'Broadway',
#  'Vladimir Script',
#  'Calibri',
#  'Kunstler Script',
#  'Lucida Console',
#  'Arial',
#  'Corbel',
#  'HCR Batang',
#  'Garamond',
#  'Leelawadee UI',
#  'HYGungSo-Bold',
#  'Wide Latin',
#  'HYPost-Medium',
#  'Book Antiqua',
#  'Rockwell Condensed',
#  'Mistral',
#  'Verdana',
#  'Lucida Bright',
#  'Trebuchet MS',
#  'Vivaldi',
#  'Yu Gothic',
#  'Freestyle Script',
#  'Webdings',
#  'Nirmala UI',
#  'Gulim',
#  'Microsoft Himalaya',
#  'Symbol',
#  'Curlz MT',
#  'Segoe UI',
#  'Elephant',
#  'HCR Batang ExtB',
#  'Bookman Old Style',
#  'Microsoft Yi Baiti',
#  'Perpetua Titling MT',
#  'Pyunji R',
#  'Informal Roman',
#  'Segoe UI Variable',
#  'Palatino Linotype',
#  'Segoe UI',
#  'Georgia',
#  'Lucida Sans Typewriter',
#  'Snap ITC',
#  'Courier New',
#  'Lucida Sans Typewriter',
#  'Microsoft Tai Le',
#  'Lucida Sans',
#  'Arial',
#  'Gloucester MT Extra Condensed',
#  'Segoe Print',
#  'Gill Sans MT Condensed',
#  'High Tower Text',
#  'Bodoni MT',
#  'Constantia',
#  'Berlin Sans FB',
#  'Arial',
#  'Bodoni MT',
#  'Rockwell Condensed',
#  'Hancom Gothic',
#  'Onyx',
#  'Engravers MT',
#  'Juice ITC',
#  'Candara',
#  'Trebuchet MS',
#  'Perpetua',
#  'Forte',
#  'Colonna MT',
#  'Bodoni MT',
#  'Wingdings 3',
#  'Segoe UI',
#  'Eras Medium ITC',
#  'Garamond',
#  'Segoe UI',
#  'Kristen ITC',
#  'Eras Bold ITC',
#  'Harlow Solid Italic',
#  'Calisto MT',
#  'Ami R',
#  'Script MT Bold',
#  'Corbel',
#  'Corbel',
#  'Berlin Sans FB Demi',
#  'Rage Italic',
#  'Californian FB',
#  'Bodoni MT',
#  'Arial',
#  'HYShortSamul-Medium',
#  'Edwardian Script ITC',
#  'Microsoft Tai Le',
#  'Old English Text MT',
#  'Microsoft YaHei',
#  'Franklin Gothic Book',
#  'Bodoni MT',
#  'Goudy Stout',
#  'Microsoft PhagsPa',
#  'Myanmar Text',
#  'Constantia',
#  'Segoe UI',
#  'Calibri',
#  'Candara',
#  'HyhwpEQ',
#  'Franklin Gothic Book',
#  'Sylfaen',
#  'Century Gothic',
#  'Algerian',
#  'Palace Script MT',
#  'Rockwell',
#  'Baskerville Old Face',
#  'Georgia',
#  'Book Antiqua',
#  'MingLiU-ExtB',
#  'Gill Sans MT',
#  'Segoe UI Emoji',
#  'Segoe Script',
#  'Times New Roman',
#  'Candara',
#  'Arial',
#  'Segoe UI',
#  'Consolas',
#  'Segoe MDL2 Assets',
#  'Bauhaus 93',
#  'Ebrima',
#  'Headline R',
#  'Han Santteut Dotum',
#  'Centaur',
#  'Franklin Gothic Demi',
#  'Microsoft New Tai Lue',
#  'Bell MT',
#  'Consolas',
#  'Bookshelf Symbol 7',
#  'Javanese Text',
#  'Bodoni MT',
#  'Microsoft Sans Serif',
#  'Bell MT',
#  'Calibri',
#  'Han Santteut Dotum',
#  'Arial Rounded MT Bold',
#  'Magneto',
#  'Perpetua',
#  'Segoe UI',
#  'Gill Sans MT',
#  'Maiandra GD',
#  'Calibri',
#  'Courier New',
#  'Franklin Gothic Heavy',
#  'Lucida Bright',
#  'Rockwell',
#  'Sans Serif Collection',
#  'Goudy Old Style',
#  'Bell MT',
#  'Leelawadee UI',
#  'Brush Script MT',
#  'Consolas',
#  'Tw Cen MT',
#  'Segoe Script',
#  'Lucida Sans',
#  'Goudy Old Style',
#  'Corbel',
#  'Tw Cen MT Condensed',
#  'Tw Cen MT',
#  'MS Outlook',
#  'Century Schoolbook',
#  'Mongolian Baiti',
#  'Calisto MT',
#  'Century Gothic',
#  'Yu Gothic']

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1],[-5, -1, 2])
