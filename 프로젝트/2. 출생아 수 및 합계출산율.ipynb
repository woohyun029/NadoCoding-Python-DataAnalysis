# %% [markdown]
# # 2.출생아 수 및 합계출산율

# %%
import pandas as pd
df = pd.read_excel('142801_20260222235420556_excel.xlsx', skiprows=2, nrows=2, index_col = 0)
df
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            2015     2016     2017     2018     2019     2020     2021  \
# 출생아 수   438.400  406.200  357.800  326.800  302.700  272.300  260.600
# 합계 출산율    1.239    1.172    1.052    0.977    0.918    0.837    0.808
#
#            2022     2023     2024
# 출생아 수   249.200  230.000  238.300
# 합계 출산율    0.778    0.721    0.748

# %%
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values # 유니코드의 띄어쓰기를 표현하는 문장 표현으로 인해 df['출생아 수'] 코드가 실행되지 않는다
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index={'출생아\xa0수':'출생아 수', '합계\xa0출산율':'합계 출산율'}, inplace=True)
df
# Out:
#            2015     2016     2017     2018     2019     2020     2021  \
# 출생아 수   438.400  406.200  357.800  326.800  302.700  272.300  260.600
# 합계 출산율    1.239    1.172    1.052    0.977    0.918    0.837    0.808
#
#            2022     2023     2024
# 출생아 수   249.200  230.000  238.300
# 합계 출산율    0.778    0.721    0.748

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# 2022    249.2
# 2023    230.0
# 2024    238.3
# Name: 출생아 수, dtype: float64

# %%
df.iloc[0] # 복잡하게 index 명을 바꾸지 않고, iloc을 통해서 불러올 수 있다
# Out:
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# 2021    260.6
# 2022    249.2
# 2023    230.0
# 2024    238.3
# Name: 출생아 수, dtype: float64

# %%
df.iloc[1]
# Out:
# 2015    1.239
# 2016    1.172
# 2017    1.052
# 2018    0.977
# 2019    0.918
# 2020    0.837
# 2021    0.808
# 2022    0.778
# 2023    0.721
# 2024    0.748
# Name: 합계 출산율, dtype: float64

# %%
df
# Out:
#            2015     2016     2017     2018     2019     2020     2021  \
# 출생아 수   438.400  406.200  357.800  326.800  302.700  272.300  260.600
# 합계 출산율    1.239    1.172    1.052    0.977    0.918    0.837    0.808
#
#            2022     2023     2024
# 출생아 수   249.200  230.000  238.300
# 합계 출산율    0.778    0.721    0.748

# %%
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.837
# 2021  260.6   0.808
# 2022  249.2   0.778
# 2023  230.0   0.721
# 2024  238.3   0.748

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(df.index, df['출생아 수'])
plt.plot(df.index, df['합계 출산율'])

# %%
fig, ax1 = plt.subplots(figsize=(10, 7))
ax1.plot(df.index, df['출생아 수'], color='#ff812d')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis 생성
ax2.plot(df.index, df['합계 출산율'], color='#ffd100')

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(0, 500)
ax1.set_yticks([100,200,300,400])
ax1.bar(df.index, df['출생아 수'], color='#ff812d')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis 생성
ax2.set_ylabel('합게 출산율 (가임여성 1명당 명')
ax2.set_ylim(0, 1.3)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], color='#ffd100')

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(0, 500)
ax1.set_yticks([100,200,300,400])
ax1.bar(df.index, df['출생아 수'], color='#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha='center')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis 생성
ax2.set_ylabel('합게 출산율 (가임여성 1명당 명')
ax2.set_ylim(0, 1.3)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], color='#ffd100')

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(200, 700)
ax1.set_yticks([300, 400, 500, 600])
ax1.bar(df.index, df['출생아 수'], color='#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha='center')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis 생성
ax2.set_ylabel('합게 출산율 (가임여성 1명당 명')
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], color='#ffd100', marker='o', ms=15, lw=5, mec='w', mew=3)

# %%
fig, ax1 = plt.subplots(figsize=(13, 5))
fig.suptitle('출생아 수 및 합계출산율')
ax1.set_ylabel('출생아 수 (천 명)')
ax1.set_ylim(200, 700)
ax1.set_yticks([300, 400, 500, 600])
ax1.bar(df.index, df['출생아 수'], color='#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha='center')

ax2 = ax1.twinx() # x축을 공유하는 쌍둥이 axis 생성
ax2.set_ylabel('합게 출산율 (가임여성 1명당 명')
ax2.set_ylim(0, 1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], color='#ffd100', marker='o', ms=15, lw=5, mec='w', mew=3)
for idx, val in enumerate(df['합계 출산율']):
    ax2.text(idx, val + 0.08, val, ha='center')
